# %% [markdown]
# <a href="https://colab.research.google.com/github/intencjusz/machine-learning/blob/main/unsupervised/03_association_rules/02_apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

pd.set_option('display.float_format', lambda x: f'{x:.2f}')

# %% [markdown]
# Załadownaie danych

# %%
# !wget https://storage.googleapis.com/esmartdata-courses-files/ml-course/products.csv
# !wget https://storage.googleapis.com/esmartdata-courses-files/ml-course/orders.csv
# Out:
# --2025-01-06 13:55:33--  https://storage.googleapis.com/esmartdata-courses-files/ml-course/products.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.207, 74.125.197.207, 74.125.135.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2166953 (2.1M) [application/octet-stream]
# Saving to: ‘products.csv’
#
# products.csv        100%[===================>]   2.07M  1.99MB/s    in 1.0s
#
# 2025-01-06 13:55:35 (1.99 MB/s) - ‘products.csv’ saved [2166953/2166953]
#
# --2025-01-06 13:55:35--  https://storage.googleapis.com/esmartdata-courses-files/ml-course/orders.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.207, 74.125.197.207, 74.125.135.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24680147 (24M) [application/octet-stream]
# Saving to: ‘orders.csv’
#
# orders.csv          100%[===================>]  23.54M  12.1MB/s    in 1.9s
#
# 2025-01-06 13:55:38 (12.1 MB/s) - ‘orders.csv’ saved [24680147/24680147]

# %%
products = pd.read_csv('products.csv', usecols=['product_id', 'product_name'])
products.head()
# Out:
#    product_id                                       product_name
# 0           1                         Chocolate Sandwich Cookies
# 1           2                                   All-Seasons Salt
# 2           3               Robust Golden Unsweetened Oolong Tea
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           5                          Green Chile Anytime Sauce

# %%
orders = pd.read_csv('orders.csv', usecols=['order_id', 'product_id'])
orders.head()
# Out:
#    order_id  product_id
# 0         1       49302
# 1         1       11109
# 2         1       10246
# 3         1       49683
# 4         1       43633

# %% [markdown]
# Przygotowanie danych

# %%
data = pd.merge(orders, products, how='inner', on='product_id', sort=True)
data = data.sort_values(by='order_id')
data.head()
# Out:
#          order_id  product_id                                   product_name
# 588447          1       22035                    Organic Whole String Cheese
# 256931          1       10246                          Organic Celery Hearts
# 277441          1       11109  Organic 4% Milk Fat Whole Milk Cottage Cheese
# 1194893         1       43633           Lightly Smoked Sardines in Olive Oil
# 1302365         1       47209                           Organic Hass Avocado

# %%
data.describe()
# Out:
#         order_id  product_id
# count 1384617.00  1384617.00
# mean  1706297.62    25556.24
# std    989732.65    14121.27
# min         1.00        1.00
# 25%    843370.00    13380.00
# 50%   1701880.00    25298.00
# 75%   2568023.00    37940.00
# max   3421070.00    49688.00

# %%
# rozkład produktów
data['product_name'].value_counts()
# Out:
# product_name
# Banana                                                               18726
# Bag of Organic Bananas                                               15480
# Organic Strawberries                                                 10894
# Organic Baby Spinach                                                  9784
# Large Lemon                                                           8135
#                                                                      ...
# Original Raincoast Oat Crisp                                             1
# Petite Creme Lowfat Strawberry Yogurt                                    1
# Organic Petite Creme Mon Cherry Amour Yogurt                             1
# Greek 100 Calories Whips! Peaches 'n Cream Fat Free Yogurt Mousse        1
# Plain Golden Toasted Bread Crumbs                                        1
# Name: count, Length: 39123, dtype: int64

# %%
# liczba transakcji
data['order_id'].nunique()
# Out:
# 131209

# %%
transactions = data.groupby(by='order_id')['product_name'].apply(lambda name: ','.join(name))
transactions
# Out:
# order_id
# 1          Organic Whole String Cheese,Organic Celery Hea...
# 36         Super Greens Salad,Spring Water,Organic Garnet...
# 38         Green Peas,Organic Baby Arugula,Shelled Pistac...
# 96         Organic Raspberries,Organic Pomegranate Kernel...
# 98         Uncured Applewood Smoked Bacon,Black Beans,Org...
#                                  ...
# 3421049    Gluten Free Rice Bread,Organic Baby Broccoli,O...
# 3421056    Sparkling Lemon Water,Brioche Buns,Homestyle C...
# 3421058    Classic Britannia Crisps,Club Soda Lower Sodiu...
# 3421063    Natural Artesian Water,Organic Half & Half,Twi...
# 3421070    Broccoli Florettes,Organic Unsweetened Almond ...
# Name: product_name, Length: 131209, dtype: object

# %%
transactions = transactions.str.split(',')
transactions

print(type(transactions))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Kodowanie transakcji

# %%
from mlxtend.preprocessing import TransactionEncoder

encoder = TransactionEncoder()
encoder.fit(transactions)
transactions_encoded = encoder.transform(transactions, sparse=True)

print(transactions_encoded)
# Out:
#   (0, 25459)	True
#   (0, 24067)	True
#   (0, 24553)	True
#   (0, 20081)	True
#   (0, 27342)	True
#   (0, 11193)	True
#   (0, 5041)	True
#   (0, 6817)	True
#   (1, 25225)	True
#   (1, 35787)	True
#   (1, 30295)	True
#   (1, 263)	True
#   (1, 7101)	True
#   (1, 25442)	True
#   (1, 4698)	True
#   (1, 16376)	True
#   (1, 34920)	True
#   (2, 14349)	True
#   (2, 24198)	True
#   (2, 33126)	True
#   (2, 469)	True
#   (2, 26410)	True
#   (2, 13842)	True
#   (2, 6825)	True
#   (2, 25540)	True
#   :	:
#   (131204, 19723)	True
#   (131204, 27299)	True
#   (131204, 24200)	True
#   (131204, 25341)	True
#   (131204, 15677)	True
#   (131205, 36413)	True
#   (131205, 34485)	True
#   (131205, 6589)	True
#   (131205, 37204)	True
#   (131205, 17627)	True
#   (131206, 4885)	True
#   (131206, 13257)	True
#   (131206, 39971)	True
#   (131206, 9738)	True
#   (131206, 36153)	True
#   (131206, 9329)	True
#   (131206, 15149)	True
#   (131206, 39426)	True
#   (131207, 25442)	True
#   (131207, 37705)	True
#   (131207, 23173)	True
#   (131207, 22642)	True
#   (131208, 6628)	True
#   (131208, 27112)	True
#   (131208, 10871)	True

# %%
transactions_encoded_df = pd.DataFrame(transactions_encoded.toarray(), columns=encoder.columns_)
transactions_encoded_df
# Out:
#                  Apricot & Banana Stage 2 Baby Food    Broad Spectrum SPF 30  \
# 0       False                                 False                    False
# 1       False                                 False                    False
# 2       False                                 False                    False
# 3       False                                 False                    False
# 4       False                                 False                    False
# ...       ...                                   ...                      ...
# 131204  False                                 False                    False
# 131205  False                                 False                    False
# 131206  False                                 False                    False
# 131207  False                                 False                    False
# 131208  False                                 False                    False
#
#           Instant    Livermore Valley    Low Sodium Marinara    Premium  \
# 0           False               False                  False      False
# 1           False               False                  False      False
# 2           False               False                  False      False
# 3           False               False                  False      False
# 4           False               False                  False      False
# ...           ...                 ...                    ...        ...
# 131204      False               False                  False      False
# 131205      False               False                  False      False
# 131206      False               False                  False      False
# 131207      False               False                  False      False
# 131208      False               False                  False      False
#
#           Vetiver scent    Whole     #2  ...  \
# 0                 False    False  False  ...
# 1                 False    False  False  ...
# 2                 False    False  False  ...
# 3                 False    False  False  ...
# 4                 False    False  False  ...
# ...                 ...      ...    ...  ...
# 131204            False    False  False  ...
# 131205            False    False  False  ...
# 131206            False    False  False  ...
# 131207            False    False  False  ...
# 131208            False    False  False  ...
#
#         with Xylitol Cinnamon 18 Sticks Sugar Free Gum  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 131204                                           False
# 131205                                           False
# 131206                                           False
# 131207                                           False
# 131208                                           False
#
#         with Xylitol Island Berry Lime 18 Sticks Sugar Free Gum  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 131204                                              False
# 131205                                              False
# 131206                                              False
# 131207                                              False
# 131208                                              False
#
#         with Xylitol Minty Sweet Twist 18 Sticks Sugar Free Gum  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 131204                                              False
# 131205                                              False
# 131206                                              False
# 131207                                              False
# 131208                                              False
#
#         with Xylitol Original Flavor 18 Sticks Sugar Free Gum  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 131204                                              False
# 131205                                              False
# 131206                                              False
# 131207                                              False
# 131208                                              False
#
#         with Xylitol Unwrapped Original Flavor 50 Sticks Sugar Free Gum  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 131204                                              False
# 131205                                              False
# 131206                                              False
# 131207                                              False
# 131208                                              False
#
#         with Xylitol Unwrapped Spearmint 50 Sticks Sugar Free Gum  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 131204                                              False
# 131205                                              False
# 131206                                              False
# 131207                                              False
# 131208                                              False
#
#         with Xylitol Watermelon Twist 18 Sticks Sugar Free Gum  \
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 131204                                              False
# 131205                                              False
# 131206                                              False
# 131207                                              False
# 131208                                              False
#
#         with a Splash of Mango Coconut Water  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 131204                                 False
# 131205                                 False
# 131206                                 False
# 131207                                 False
# 131208                                 False
#
#         with a Splash of Pineapple Coconut Water  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 131204                                     False
# 131205                                     False
# 131206                                     False
# 131207                                     False
# 131208                                     False
#
#          Lightly Seasoned with Rosemary and Roasted Garlic Family Size Herb Chicken Tortellini
# 0                                                   False
# 1                                                   False
# 2                                                   False
# 3                                                   False
# 4                                                   False
# ...                                                   ...
# 131204                                              False
# 131205                                              False
# 131206                                              False
# 131207                                              False
# 131208                                              False
#
# [131209 rows x 40434 columns]

# %% [markdown]
# Algorytm Apriori

# %%
from mlxtend.frequent_patterns import apriori, association_rules

supports = apriori(transactions_encoded_df, min_support=0.01, use_colnames=True)
supports = supports.sort_values(by='support', ascending=False)
supports.head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support                  itemsets
# 8       0.14                  (Banana)
# 7       0.12  (Bag of Organic Bananas)
# 76      0.08    (Organic Strawberries)
# 41      0.07    (Organic Baby Spinach)
# 31      0.06             (Large Lemon)
# 37      0.06         (Organic Avocado)
# 61      0.06    (Organic Hass Avocado)
# 100     0.05            (Strawberries)
# 33      0.05                   (Limes)
# 69      0.04     (Organic Raspberries)

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Tworzymy zestawy częstych elementów
supports = apriori(transactions_encoded_df, min_support=0.01, use_colnames=True)

# Określamy liczbę elementów w zestawach
num_itemsets = len(supports)

# Używamy poprawnych argumentów dla association_rules
rules = association_rules(supports, metric='confidence', min_threshold=0.0, num_itemsets=num_itemsets)
rules = rules.iloc[:, [0, 1, 4, 5, 6]]  # Możesz dostosować kolumny, które chcesz wyświetlić
rules = rules.sort_values(by='lift', ascending=False)
rules.head(15)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                  antecedents               consequents  support  confidence  \
# 0              (Clementines)                    ( Bag)     0.01        0.52
# 1                     ( Bag)             (Clementines)     0.01        0.79
# 23                   (Limes)             (Large Lemon)     0.01        0.26
# 22             (Large Lemon)                   (Limes)     0.01        0.20
# 32     (Organic Raspberries)    (Organic Strawberries)     0.01        0.30
# 33    (Organic Strawberries)     (Organic Raspberries)     0.01        0.15
# 25             (Large Lemon)         (Organic Avocado)     0.01        0.17
# 24         (Organic Avocado)             (Large Lemon)     0.01        0.18
# 4     (Organic Hass Avocado)  (Bag of Organic Bananas)     0.02        0.33
# 5   (Bag of Organic Bananas)    (Organic Hass Avocado)     0.02        0.16
# 6      (Organic Raspberries)  (Bag of Organic Bananas)     0.01        0.32
# 7   (Bag of Organic Bananas)     (Organic Raspberries)     0.01        0.11
# 31    (Organic Strawberries)    (Organic Hass Avocado)     0.01        0.14
# 30    (Organic Hass Avocado)    (Organic Strawberries)     0.01        0.21
# 27    (Organic Baby Spinach)         (Organic Avocado)     0.01        0.14
#
#     lift
# 0  36.84
# 1  36.84
# 23  4.26
# 22  4.26
# 32  3.63
# 33  3.63
# 25  2.94
# 24  2.94
# 4   2.81
# 5   2.81
# 6   2.72
# 7   2.72
# 31  2.54
# 30  2.54
# 27  2.54
